# %%
import pandas as pd #to read the data
from sklearn.linear_model import LogisticRegression #To use lr to make prediction
from sklearn.model_selection import train_test_split #to split the data into train and test
import warnings #ignore the warnings
warnings.filterwarnings("ignore")
df=pd.read_csv("earth.csv")

# %%
df
# Out:
#             Date      Time  Latitude  Longitude   Depth  Depth Error  \
# 0       1/1/2000   5:58:20  -60.7220   153.6700   10.00          4.7
# 1       1/2/2000  12:14:39  -17.9430  -178.4760  582.30          4.7
# 2       1/2/2000  12:58:42   51.4470  -175.5580   33.00          4.7
# 3       1/2/2000  15:16:32  -20.7710  -174.2360   33.00          4.7
# 4       1/5/2000   7:32:19  -20.9640  -174.0970   33.00          4.7
# ...          ...       ...       ...        ...     ...          ...
# 8739  12/28/2016   8:22:12   38.3917  -118.8941   12.30          1.2
# 8740  12/28/2016   9:13:47   38.3777  -118.8957    8.80          2.0
# 8741  12/28/2016  12:38:51   36.9179   140.4262   10.00          1.8
# 8742  12/29/2016  22:30:19   -9.0283   118.6639   79.00          1.8
# 8743  12/30/2016  20:08:28   37.3973   141.4103   11.94          2.2
#
#       Depth Seismic Stations  Magnitude  Magnitude Type  Magnitude Error  \
# 0                        158        6.0               0            0.030
# 1                        473        5.5               0            0.041
# 2                        149        5.8               0            0.071
# 3                        169        5.8               1            0.000
# 4                        116        5.6               0            0.045
# ...                      ...        ...             ...              ...
# 8739                      40        5.6               6            0.320
# 8740                      33        5.5               6            0.260
# 8741                      33        5.9               2            0.000
# 8742                      33        6.3               2            0.000
# 8743                      33        5.5               3            0.029
#
#       Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                              4         228.00               0.6946
# 1                              4         228.00               0.6946
# 2                              4         228.00               0.6946
# 3                              4         228.00               0.6946
# 4                              4         228.00               0.6946
# ...                          ...            ...                  ...
# 8739                          18          42.47               0.1200
# 8740                          18          48.58               0.1290
# 8741                          18          91.00               0.9920
# 8742                          18          26.00               3.5530
# 8743                         428          97.00               0.6810
#
#       Horizontal Error  Root Mean Square  Status
# 0                  1.5            1.0500       1
# 1                  1.5            0.8700       1
# 2                  1.5            0.9800       1
# 3                  1.5            1.3200       1
# 4                  1.5            0.9100       1
# ...                ...               ...     ...
# 8739               5.1            0.1898       1
# 8740               5.1            0.2187       1
# 8741               4.8            1.5200       1
# 8742               6.0            1.4300       1
# 8743               4.5            0.9100       1
#
# [8744 rows x 16 columns]

# %%
df.shape
# Out:
# (8744, 16)

# %%
df.size
# Out:
# 139904

# %%
df.head()
# Out:
#        Date      Time  Latitude  Longitude  Depth  Depth Error  \
# 0  1/1/2000   5:58:20   -60.722    153.670   10.0          4.7
# 1  1/2/2000  12:14:39   -17.943   -178.476  582.3          4.7
# 2  1/2/2000  12:58:42    51.447   -175.558   33.0          4.7
# 3  1/2/2000  15:16:32   -20.771   -174.236   33.0          4.7
# 4  1/5/2000   7:32:19   -20.964   -174.097   33.0          4.7
#
#    Depth Seismic Stations  Magnitude  Magnitude Type  Magnitude Error  \
# 0                     158        6.0               0            0.030
# 1                     473        5.5               0            0.041
# 2                     149        5.8               0            0.071
# 3                     169        5.8               1            0.000
# 4                     116        5.6               0            0.045
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                           4          228.0               0.6946
# 1                           4          228.0               0.6946
# 2                           4          228.0               0.6946
# 3                           4          228.0               0.6946
# 4                           4          228.0               0.6946
#
#    Horizontal Error  Root Mean Square  Status
# 0               1.5              1.05       1
# 1               1.5              0.87       1
# 2               1.5              0.98       1
# 3               1.5              1.32       1
# 4               1.5              0.91       1

# %%
df.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8744 entries, 0 to 8743
# Columns: 16 entries, Date to Status
# dtypes: float64(10), int64(4), object(2)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#           Latitude    Longitude        Depth  Depth Error  \
# count  8744.000000  8744.000000  8744.000000  8744.000000
# mean     -0.163256    38.567276    65.812670     6.742312
# std      29.651578   124.569864   124.386646     5.746148
# min     -77.080000  -179.996000     0.000000     0.000000
# 25%     -19.717725   -76.012500    10.000000     2.900000
# 50%      -4.117750    98.607250    25.000000     5.050000
# 75%      22.360500   143.535250    44.200000     8.700000
# max      86.005000   179.998000   691.600000    43.700000
#
#        Depth Seismic Stations    Magnitude  Magnitude Type  Magnitude Error  \
# count             8744.000000  8744.000000     8744.000000      8744.000000
# mean               232.308783     5.877395        0.924634         0.024010
# std                175.204819     0.428123        1.050445         0.037211
# min                  5.000000     5.500000        0.000000         0.000000
# 25%                 80.000000     5.600000        0.000000         0.000000
# 50%                209.000000     5.700000        1.000000         0.000000
# 75%                353.000000     6.000000        2.000000         0.049000
# max                934.000000     9.100000        6.000000         0.350000
#
#        Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# count                 8744.000000    8744.000000          8744.000000
# mean                    85.052036      66.867752             0.947285
# std                     90.780883      67.782994             2.751548
# min                      0.000000       8.000000             0.008000
# 25%                     24.000000      26.300000             0.046850
# 50%                     51.000000      38.950000             0.318000
# 75%                    125.000000      67.000000             0.694600
# max                    821.000000     313.000000            37.874000
#
#        Horizontal Error  Root Mean Square       Status
# count       8744.000000       8744.000000  8744.000000
# mean           1.819903          0.978988     0.679666
# std            2.281790          0.184047     0.466632
# min            0.110000          0.040000     0.000000
# 25%            0.160000          0.850000     0.000000
# 50%            1.500000          0.960000     1.000000
# 75%            1.900000          1.090000     1.000000
# max           15.800000          2.110000     1.000000

# %%
df.isnull()
# Out:
#        Date   Time  Latitude  Longitude  Depth  Depth Error  \
# 0     False  False     False      False  False        False
# 1     False  False     False      False  False        False
# 2     False  False     False      False  False        False
# 3     False  False     False      False  False        False
# 4     False  False     False      False  False        False
# ...     ...    ...       ...        ...    ...          ...
# 8739  False  False     False      False  False        False
# 8740  False  False     False      False  False        False
# 8741  False  False     False      False  False        False
# 8742  False  False     False      False  False        False
# 8743  False  False     False      False  False        False
#
#       Depth Seismic Stations  Magnitude  Magnitude Type  Magnitude Error  \
# 0                      False      False           False            False
# 1                      False      False           False            False
# 2                      False      False           False            False
# 3                      False      False           False            False
# 4                      False      False           False            False
# ...                      ...        ...             ...              ...
# 8739                   False      False           False            False
# 8740                   False      False           False            False
# 8741                   False      False           False            False
# 8742                   False      False           False            False
# 8743                   False      False           False            False
#
#       Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                          False          False                False
# 1                          False          False                False
# 2                          False          False                False
# 3                          False          False                False
# 4                          False          False                False
# ...                          ...            ...                  ...
# 8739                       False          False                False
# 8740                       False          False                False
# 8741                       False          False                False
# 8742                       False          False                False
# 8743                       False          False                False
#
#       Horizontal Error  Root Mean Square  Status
# 0                False             False   False
# 1                False             False   False
# 2                False             False   False
# 3                False             False   False
# 4                False             False   False
# ...                ...               ...     ...
# 8739             False             False   False
# 8740             False             False   False
# 8741             False             False   False
# 8742             False             False   False
# 8743             False             False   False
#
# [8744 rows x 16 columns]

# %%
df.isnull().sum()
# Out:
# Date                          0
# Time                          0
# Latitude                      0
# Longitude                     0
# Depth                         0
# Depth Error                   0
# Depth Seismic Stations        0
# Magnitude                     0
# Magnitude Type                0
# Magnitude Error               0
# Magnitude Seismic Stations    0
# Azimuthal Gap                 0
# Horizontal Distance           0
# Horizontal Error              0
# Root Mean Square              0
# Status                        0
# dtype: int64

# %%
df.dtypes
# Out:
# Date                           object
# Time                           object
# Latitude                      float64
# Longitude                     float64
# Depth                         float64
# Depth Error                   float64
# Depth Seismic Stations          int64
# Magnitude                     float64
# Magnitude Type                  int64
# Magnitude Error               float64
# Magnitude Seismic Stations      int64
# Azimuthal Gap                 float64
# Horizontal Distance           float64
# Horizontal Error              float64
# Root Mean Square              float64
# Status                          int64
# dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#data visulisation purpose

# %%
df
# Out:
#             Date      Time  Latitude  Longitude   Depth  Depth Error  \
# 0       1/1/2000   5:58:20  -60.7220   153.6700   10.00          4.7
# 1       1/2/2000  12:14:39  -17.9430  -178.4760  582.30          4.7
# 2       1/2/2000  12:58:42   51.4470  -175.5580   33.00          4.7
# 3       1/2/2000  15:16:32  -20.7710  -174.2360   33.00          4.7
# 4       1/5/2000   7:32:19  -20.9640  -174.0970   33.00          4.7
# ...          ...       ...       ...        ...     ...          ...
# 8739  12/28/2016   8:22:12   38.3917  -118.8941   12.30          1.2
# 8740  12/28/2016   9:13:47   38.3777  -118.8957    8.80          2.0
# 8741  12/28/2016  12:38:51   36.9179   140.4262   10.00          1.8
# 8742  12/29/2016  22:30:19   -9.0283   118.6639   79.00          1.8
# 8743  12/30/2016  20:08:28   37.3973   141.4103   11.94          2.2
#
#       Depth Seismic Stations  Magnitude  Magnitude Type  Magnitude Error  \
# 0                        158        6.0               0            0.030
# 1                        473        5.5               0            0.041
# 2                        149        5.8               0            0.071
# 3                        169        5.8               1            0.000
# 4                        116        5.6               0            0.045
# ...                      ...        ...             ...              ...
# 8739                      40        5.6               6            0.320
# 8740                      33        5.5               6            0.260
# 8741                      33        5.9               2            0.000
# 8742                      33        6.3               2            0.000
# 8743                      33        5.5               3            0.029
#
#       Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                              4         228.00               0.6946
# 1                              4         228.00               0.6946
# 2                              4         228.00               0.6946
# 3                              4         228.00               0.6946
# 4                              4         228.00               0.6946
# ...                          ...            ...                  ...
# 8739                          18          42.47               0.1200
# 8740                          18          48.58               0.1290
# 8741                          18          91.00               0.9920
# 8742                          18          26.00               3.5530
# 8743                         428          97.00               0.6810
#
#       Horizontal Error  Root Mean Square  Status
# 0                  1.5            1.0500       1
# 1                  1.5            0.8700       1
# 2                  1.5            0.9800       1
# 3                  1.5            1.3200       1
# 4                  1.5            0.9100       1
# ...                ...               ...     ...
# 8739               5.1            0.1898       1
# 8740               5.1            0.2187       1
# 8741               4.8            1.5200       1
# 8742               6.0            1.4300       1
# 8743               4.5            0.9100       1
#
# [8744 rows x 16 columns]

# %%
df
# Out:
#             Date      Time  Latitude  Longitude   Depth  Depth Error  \
# 0       1/1/2000   5:58:20  -60.7220   153.6700   10.00          4.7
# 1       1/2/2000  12:14:39  -17.9430  -178.4760  582.30          4.7
# 2       1/2/2000  12:58:42   51.4470  -175.5580   33.00          4.7
# 3       1/2/2000  15:16:32  -20.7710  -174.2360   33.00          4.7
# 4       1/5/2000   7:32:19  -20.9640  -174.0970   33.00          4.7
# ...          ...       ...       ...        ...     ...          ...
# 8739  12/28/2016   8:22:12   38.3917  -118.8941   12.30          1.2
# 8740  12/28/2016   9:13:47   38.3777  -118.8957    8.80          2.0
# 8741  12/28/2016  12:38:51   36.9179   140.4262   10.00          1.8
# 8742  12/29/2016  22:30:19   -9.0283   118.6639   79.00          1.8
# 8743  12/30/2016  20:08:28   37.3973   141.4103   11.94          2.2
#
#       Depth Seismic Stations  Magnitude  Magnitude Type  Magnitude Error  \
# 0                        158        6.0               0            0.030
# 1                        473        5.5               0            0.041
# 2                        149        5.8               0            0.071
# 3                        169        5.8               1            0.000
# 4                        116        5.6               0            0.045
# ...                      ...        ...             ...              ...
# 8739                      40        5.6               6            0.320
# 8740                      33        5.5               6            0.260
# 8741                      33        5.9               2            0.000
# 8742                      33        6.3               2            0.000
# 8743                      33        5.5               3            0.029
#
#       Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                              4         228.00               0.6946
# 1                              4         228.00               0.6946
# 2                              4         228.00               0.6946
# 3                              4         228.00               0.6946
# 4                              4         228.00               0.6946
# ...                          ...            ...                  ...
# 8739                          18          42.47               0.1200
# 8740                          18          48.58               0.1290
# 8741                          18          91.00               0.9920
# 8742                          18          26.00               3.5530
# 8743                         428          97.00               0.6810
#
#       Horizontal Error  Root Mean Square  Status
# 0                  1.5            1.0500       1
# 1                  1.5            0.8700       1
# 2                  1.5            0.9800       1
# 3                  1.5            1.3200       1
# 4                  1.5            0.9100       1
# ...                ...               ...     ...
# 8739               5.1            0.1898       1
# 8740               5.1            0.2187       1
# 8741               4.8            1.5200       1
# 8742               6.0            1.4300       1
# 8743               4.5            0.9100       1
#
# [8744 rows x 16 columns]

# %%
plt.subplots(figsize=(800,10))
sns.countplot(x='Longitude',data=df)
# Out:
# <AxesSubplot:xlabel='Longitude', ylabel='count'>
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x0000019BF305D0D0> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\pyplot.py in post_execute()
#     135     def post_execute():
#     136         if matplotlib.is_interactive():
# --> 137             draw_all()
#     138
#     139     try:  # IPython >= 2
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\_pylab_helpers.py in draw_all(cls, force)
#     139         for manager in cls.get_all_fig_managers():
#     140             if force or manager.canvas.figure.stale:
# --> 141                 manager.canvas.draw_idle()
#     142
#     143
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backend_bases.py in draw_idle(self, *args, **kwargs)
#    2058         if not self._is_idle_drawing:
#    2059             with self._idle_draw_cntx():
# -> 2060                 self.draw(*args, **kwargs)
#    2061
#    2062     @property
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     429     def draw(self):
#     430         # docstring inherited
# --> 431         self.renderer = self.get_renderer(cleared=True)
#     432         # Acquire a lock on the shared font cache.
#     433         with RendererAgg.lock, \
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py in get_renderer(self, cleared)
#     445                           and getattr(self, "_lastKey", None) == key)
#     446         if not reuse_renderer:
# --> 447             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     448             self._lastKey = key
#     449         elif cleared:
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py in __init__(self, width, height, dpi)
#      91         self.width = width
#      92         self.height = height
# ---> 93         self._renderer = _RendererAgg(int(width), int(height), dpi)
#      94         self._filter_renderers = []
#      95
#
# ValueError: Image size of 80000x1000 pixels is too large. It must be less than 2^16 in each direction.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2290                     self.figure,
#    2291                     functools.partial(
# -> 2292                         print_method, orientation=orientation)
#    2293                 )
#    2294                 with getattr(renderer, "_draw_disabled", nullcontext)():
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backend_bases.py in _get_renderer(figure, print_method)
#    1542                 figure.canvas._get_output_canvas(None, fmt), f"print_{fmt}")
#    1543         try:
# -> 1544             print_method(io.BytesIO())
#    1545         except Done as exc:
#    1546             renderer, = figure._cachedRenderer, = exc.args
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backend_bases.py in wrapper(*args, **kwargs)
#    1646             kwargs.pop(arg)
#    1647
# -> 1648         return func(*args, **kwargs)
#    1649
#    1650     return wrapper
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     413                          else deprecation_addendum,
#     414                 **kwargs)
# --> 415         return func(*inner_args, **inner_kwargs)
#     416
#     417     DECORATORS[wrapper] = decorator
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     538             *metadata*, including the default 'Software' key.
#     539         """
# --> 540         FigureCanvasAgg.draw(self)
#     541         mpl.image.imsave(
#     542             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     429     def draw(self):
#     430         # docstring inherited
# --> 431         self.renderer = self.get_renderer(cleared=True)
#     432         # Acquire a lock on the shared font cache.
#     433         with RendererAgg.lock, \
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py in get_renderer(self, cleared)
#     445                           and getattr(self, "_lastKey", None) == key)
#     446         if not reuse_renderer:
# --> 447             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     448             self._lastKey = key
#     449         elif cleared:
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py in __init__(self, width, height, dpi)
#      91         self.width = width
#      92         self.height = height
# ---> 93         self._renderer = _RendererAgg(int(width), int(height), dpi)
#      94         self._filter_renderers = []
#      95
#
# ValueError: Image size of 80000x1000 pixels is too large. It must be less than 2^16 in each direction.

# %%
color = ('#00ffff','#ffcccc')
plt.subplots(figsize=(800,10))
sns.countplot(x='Depth',data=df,palette=color)
# Out:
# <AxesSubplot:xlabel='Depth', ylabel='count'>
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x0000019BF305D0D0> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\pyplot.py in post_execute()
#     135     def post_execute():
#     136         if matplotlib.is_interactive():
# --> 137             draw_all()
#     138
#     139     try:  # IPython >= 2
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\_pylab_helpers.py in draw_all(cls, force)
#     139         for manager in cls.get_all_fig_managers():
#     140             if force or manager.canvas.figure.stale:
# --> 141                 manager.canvas.draw_idle()
#     142
#     143
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backend_bases.py in draw_idle(self, *args, **kwargs)
#    2058         if not self._is_idle_drawing:
#    2059             with self._idle_draw_cntx():
# -> 2060                 self.draw(*args, **kwargs)
#    2061
#    2062     @property
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     429     def draw(self):
#     430         # docstring inherited
# --> 431         self.renderer = self.get_renderer(cleared=True)
#     432         # Acquire a lock on the shared font cache.
#     433         with RendererAgg.lock, \
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py in get_renderer(self, cleared)
#     445                           and getattr(self, "_lastKey", None) == key)
#     446         if not reuse_renderer:
# --> 447             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     448             self._lastKey = key
#     449         elif cleared:
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py in __init__(self, width, height, dpi)
#      91         self.width = width
#      92         self.height = height
# ---> 93         self._renderer = _RendererAgg(int(width), int(height), dpi)
#      94         self._filter_renderers = []
#      95
#
# ValueError: Image size of 80000x1000 pixels is too large. It must be less than 2^16 in each direction.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2290                     self.figure,
#    2291                     functools.partial(
# -> 2292                         print_method, orientation=orientation)
#    2293                 )
#    2294                 with getattr(renderer, "_draw_disabled", nullcontext)():
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backend_bases.py in _get_renderer(figure, print_method)
#    1542                 figure.canvas._get_output_canvas(None, fmt), f"print_{fmt}")
#    1543         try:
# -> 1544             print_method(io.BytesIO())
#    1545         except Done as exc:
#    1546             renderer, = figure._cachedRenderer, = exc.args
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backend_bases.py in wrapper(*args, **kwargs)
#    1646             kwargs.pop(arg)
#    1647
# -> 1648         return func(*args, **kwargs)
#    1649
#    1650     return wrapper
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     413                          else deprecation_addendum,
#     414                 **kwargs)
# --> 415         return func(*inner_args, **inner_kwargs)
#     416
#     417     DECORATORS[wrapper] = decorator
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     538             *metadata*, including the default 'Software' key.
#     539         """
# --> 540         FigureCanvasAgg.draw(self)
#     541         mpl.image.imsave(
#     542             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     429     def draw(self):
#     430         # docstring inherited
# --> 431         self.renderer = self.get_renderer(cleared=True)
#     432         # Acquire a lock on the shared font cache.
#     433         with RendererAgg.lock, \
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py in get_renderer(self, cleared)
#     445                           and getattr(self, "_lastKey", None) == key)
#     446         if not reuse_renderer:
# --> 447             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     448             self._lastKey = key
#     449         elif cleared:
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py in __init__(self, width, height, dpi)
#      91         self.width = width
#      92         self.height = height
# ---> 93         self._renderer = _RendererAgg(int(width), int(height), dpi)
#      94         self._filter_renderers = []
#      95
#
# ValueError: Image size of 80000x1000 pixels is too large. It must be less than 2^16 in each direction.

# %%
plt.subplots(figsize=(800,10))
sns.barplot(x='Horizontal Distance',y='Horizontal Error',data=df)
# Out:
# <AxesSubplot:xlabel='Horizontal Distance', ylabel='Horizontal Error'>
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x0000019BF305D0D0> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\pyplot.py in post_execute()
#     135     def post_execute():
#     136         if matplotlib.is_interactive():
# --> 137             draw_all()
#     138
#     139     try:  # IPython >= 2
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\_pylab_helpers.py in draw_all(cls, force)
#     139         for manager in cls.get_all_fig_managers():
#     140             if force or manager.canvas.figure.stale:
# --> 141                 manager.canvas.draw_idle()
#     142
#     143
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backend_bases.py in draw_idle(self, *args, **kwargs)
#    2058         if not self._is_idle_drawing:
#    2059             with self._idle_draw_cntx():
# -> 2060                 self.draw(*args, **kwargs)
#    2061
#    2062     @property
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     429     def draw(self):
#     430         # docstring inherited
# --> 431         self.renderer = self.get_renderer(cleared=True)
#     432         # Acquire a lock on the shared font cache.
#     433         with RendererAgg.lock, \
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py in get_renderer(self, cleared)
#     445                           and getattr(self, "_lastKey", None) == key)
#     446         if not reuse_renderer:
# --> 447             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     448             self._lastKey = key
#     449         elif cleared:
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py in __init__(self, width, height, dpi)
#      91         self.width = width
#      92         self.height = height
# ---> 93         self._renderer = _RendererAgg(int(width), int(height), dpi)
#      94         self._filter_renderers = []
#      95
#
# ValueError: Image size of 80000x1000 pixels is too large. It must be less than 2^16 in each direction.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2290                     self.figure,
#    2291                     functools.partial(
# -> 2292                         print_method, orientation=orientation)
#    2293                 )
#    2294                 with getattr(renderer, "_draw_disabled", nullcontext)():
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backend_bases.py in _get_renderer(figure, print_method)
#    1542                 figure.canvas._get_output_canvas(None, fmt), f"print_{fmt}")
#    1543         try:
# -> 1544             print_method(io.BytesIO())
#    1545         except Done as exc:
#    1546             renderer, = figure._cachedRenderer, = exc.args
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backend_bases.py in wrapper(*args, **kwargs)
#    1646             kwargs.pop(arg)
#    1647
# -> 1648         return func(*args, **kwargs)
#    1649
#    1650     return wrapper
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     413                          else deprecation_addendum,
#     414                 **kwargs)
# --> 415         return func(*inner_args, **inner_kwargs)
#     416
#     417     DECORATORS[wrapper] = decorator
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     538             *metadata*, including the default 'Software' key.
#     539         """
# --> 540         FigureCanvasAgg.draw(self)
#     541         mpl.image.imsave(
#     542             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     429     def draw(self):
#     430         # docstring inherited
# --> 431         self.renderer = self.get_renderer(cleared=True)
#     432         # Acquire a lock on the shared font cache.
#     433         with RendererAgg.lock, \
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py in get_renderer(self, cleared)
#     445                           and getattr(self, "_lastKey", None) == key)
#     446         if not reuse_renderer:
# --> 447             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     448             self._lastKey = key
#     449         elif cleared:
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py in __init__(self, width, height, dpi)
#      91         self.width = width
#      92         self.height = height
# ---> 93         self._renderer = _RendererAgg(int(width), int(height), dpi)
#      94         self._filter_renderers = []
#      95
#
# ValueError: Image size of 80000x1000 pixels is too large. It must be less than 2^16 in each direction.

# %%
plt.subplots(figsize=(800,10))
sns.lineplot(x='Horizontal Distance',y='Horizontal Error',data=df)
# Out:
# <AxesSubplot:xlabel='Horizontal Distance', ylabel='Horizontal Error'>
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x0000019BF305D0D0> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\pyplot.py in post_execute()
#     135     def post_execute():
#     136         if matplotlib.is_interactive():
# --> 137             draw_all()
#     138
#     139     try:  # IPython >= 2
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\_pylab_helpers.py in draw_all(cls, force)
#     139         for manager in cls.get_all_fig_managers():
#     140             if force or manager.canvas.figure.stale:
# --> 141                 manager.canvas.draw_idle()
#     142
#     143
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backend_bases.py in draw_idle(self, *args, **kwargs)
#    2058         if not self._is_idle_drawing:
#    2059             with self._idle_draw_cntx():
# -> 2060                 self.draw(*args, **kwargs)
#    2061
#    2062     @property
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     429     def draw(self):
#     430         # docstring inherited
# --> 431         self.renderer = self.get_renderer(cleared=True)
#     432         # Acquire a lock on the shared font cache.
#     433         with RendererAgg.lock, \
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py in get_renderer(self, cleared)
#     445                           and getattr(self, "_lastKey", None) == key)
#     446         if not reuse_renderer:
# --> 447             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     448             self._lastKey = key
#     449         elif cleared:
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py in __init__(self, width, height, dpi)
#      91         self.width = width
#      92         self.height = height
# ---> 93         self._renderer = _RendererAgg(int(width), int(height), dpi)
#      94         self._filter_renderers = []
#      95
#
# ValueError: Image size of 80000x1000 pixels is too large. It must be less than 2^16 in each direction.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2290                     self.figure,
#    2291                     functools.partial(
# -> 2292                         print_method, orientation=orientation)
#    2293                 )
#    2294                 with getattr(renderer, "_draw_disabled", nullcontext)():
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backend_bases.py in _get_renderer(figure, print_method)
#    1542                 figure.canvas._get_output_canvas(None, fmt), f"print_{fmt}")
#    1543         try:
# -> 1544             print_method(io.BytesIO())
#    1545         except Done as exc:
#    1546             renderer, = figure._cachedRenderer, = exc.args
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backend_bases.py in wrapper(*args, **kwargs)
#    1646             kwargs.pop(arg)
#    1647
# -> 1648         return func(*args, **kwargs)
#    1649
#    1650     return wrapper
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     413                          else deprecation_addendum,
#     414                 **kwargs)
# --> 415         return func(*inner_args, **inner_kwargs)
#     416
#     417     DECORATORS[wrapper] = decorator
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     538             *metadata*, including the default 'Software' key.
#     539         """
# --> 540         FigureCanvasAgg.draw(self)
#     541         mpl.image.imsave(
#     542             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     429     def draw(self):
#     430         # docstring inherited
# --> 431         self.renderer = self.get_renderer(cleared=True)
#     432         # Acquire a lock on the shared font cache.
#     433         with RendererAgg.lock, \
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py in get_renderer(self, cleared)
#     445                           and getattr(self, "_lastKey", None) == key)
#     446         if not reuse_renderer:
# --> 447             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     448             self._lastKey = key
#     449         elif cleared:
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py in __init__(self, width, height, dpi)
#      91         self.width = width
#      92         self.height = height
# ---> 93         self._renderer = _RendererAgg(int(width), int(height), dpi)
#      94         self._filter_renderers = []
#      95
#
# ValueError: Image size of 80000x1000 pixels is too large. It must be less than 2^16 in each direction.

# %%
import numpy as np

# %%
df_max=df.max()
df_max
# Out:
# Date                          9/9/2016
# Time                           9:59:57
# Latitude                        86.005
# Longitude                      179.998
# Depth                            691.6
# Depth Error                       43.7
# Depth Seismic Stations             934
# Magnitude                          9.1
# Magnitude Type                       6
# Magnitude Error                   0.35
# Magnitude Seismic Stations         821
# Azimuthal Gap                    313.0
# Horizontal Distance             37.874
# Horizontal Error                  15.8
# Root Mean Square                  2.11
# Status                               1
# dtype: object

# %%
df_min=df.min()

# %%
x_normal=(df-df_min)/(df_max-df_min)
x_normal
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     165     try:
# --> 166         result = func(left, right)
#     167     except TypeError:
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     238             # error: "None" not callable
# --> 239             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240     return _evaluate_standard(op, op_str, a, b)
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
#      68         _store_test_result(False)
# ---> 69     return op(a, b)
#      70
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25304\3262615319.py in <module>
# ----> 1 x_normal=(df-df_min)/(df_max-df_min)
#       2 x_normal
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\pandas\core\arraylike.py in __sub__(self, other)
#      98     @unpack_zerodim_and_defer("__sub__")
#      99     def __sub__(self, other):
# --> 100         return self._arith_method(other, operator.sub)
#     101
#     102     @unpack_zerodim_and_defer("__rsub__")
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in _arith_method(self, other, op)
#    6864         self, other = ops.align_method_FRAME(self, other, axis, flex=True, level=None)
#    6865
# -> 6866         new_data = self._dispatch_frame_op(other, op, axis=axis)
#    6867         return self._construct_result(new_data)
#    6868
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in _dispatch_frame_op(self, right, func, axis)
#    6911                     # "BlockManager"
#    6912                     right._mgr,  # type: ignore[arg-type]
# -> 6913                     array_op,
#    6914                 )
#    6915             return type(self)(bm)
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\pandas\core\internals\managers.py in operate_blockwise(self, other, array_op)
#    1301         Apply array_op blockwise with another (aligned) BlockManager.
#    1302         """
# -> 1303         return operate_blockwise(self, other, array_op)
#    1304
#    1305     def _equal_values(self: BlockManager, other: BlockManager) -> bool:
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\pandas\core\internals\ops.py in operate_blockwise(left, right, array_op)
#      55     res_blks: list[Block] = []
#      56     for lvals, rvals, locs, left_ea, right_ea, rblk in _iter_block_pairs(left, right):
# ---> 57         res_values = array_op(lvals, rvals)
#      58         if left_ea and not right_ea and hasattr(res_values, "reshape"):
#      59             res_values = res_values.reshape(1, -1)
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\pandas\core\ops\array_ops.py in arithmetic_op(left, right, op)
#     222         _bool_arith_check(op, left, right)
#     223
# --> 224         res_values = _na_arithmetic_op(left, right, op)
#     225
#     226     return res_values
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     171             # Don't do this for comparisons, as that will handle complex numbers
#     172             #  incorrectly, see GH#32047
# --> 173             result = _masked_arith_op(left, right, op)
#     174         else:
#     175             raise
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\pandas\core\ops\array_ops.py in _masked_arith_op(x, y, op)
#     110         # See GH#5284, GH#5035, GH#19448 for historical reference
#     111         if mask.any():
# --> 112             result[mask] = op(xrav[mask], yrav[mask])
#     113
#     114     else:
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
x_normal.isnull().sum()

# %%
df1=x_normal
df1

# %%
plt.subplots(figsize=(50,10))
sns.scatterplot(x='Latitude',y='Longitude',data=df1)

# %%
plt.subplots(figsize=(80,10))
sns.lineplot(x='Latitude',y='Longitude',data=df1)

# %%
f=plt.subplots(figsize=(20,10))
corr=df.corr()
corr=(corr)
sns.heatmap(corr,xticklabels=corr.columns.values,linewidth=0.5,yticklabels=corr.columns.values)
corr

# %%
X=df.drop(["Status"],axis=1)
Y=df["Status"]

# %%
X

# %%
Y

# %%
X_train,X_test,Y_train,Y_test= train_test_split(X,Y,test_size=0.3,random_state=0)

# %%
X_train

# %%
Y_train

# %%
logmodel=LogisticRegression()
logmodel.fit(X_train,Y_train)

# %%
predictions= logmodel.predict(X_test)
predictions

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(Y_test, predictions)
from sklearn.metrics import accuracy_score
accuracy_score(Y_test,predictions)

# %%
X_train= X_train.T
Y_train= Y_train.T
X_test= X_test.T
Y_test= Y_test.T

# %%
accuracies={}
lr = LogisticRegression()
lr.fit(X_train.T,Y_train.T)
acclr= lr.score(X_test.T, Y_test.T)*100
accuracies['Logistic Regression']=acclr
print("test accuracy {:.2f}%".format(acclr))
# Out:
# test accuracy 79.31%

# %%
from sklearn.neighbors import KNeighborsClassifier
knn= KNeighborsClassifier(n_neighbors=17)
knn.fit(X_train.T, Y_train.T)
prediction = knn.predict(X_test.T)
print("{} NN Score: {:.2f}%".format(2, knn.score(X_test.T,Y_test.T)*100))
# Out:
# 2 NN Score: 77.55%

# %%
scoreList=[]
for i in range(1,20):
    knn2 =KNeighborsClassifier(n_neighbors=i)
    knn2.fit(X_train.T,Y_train.T)
    scoreList.append(knn2.score(X_test.T,Y_test.T))
    
plt.plot(range(1,20),scoreList)
plt.xticks(np.arange(1,20,1))
plt.xlabel("K Value")
plt.ylabel("Score")
plt.show()

accknn=max(scoreList)*100
accuracies["KNN"]=accknn
print("Maximum KNN Score is {:.2f}%".format(accknn))
# Out:
# Maximum KNN Score is 77.55%

# %%
from sklearn.ensemble import RandomForestClassifier
rf =RandomForestClassifier(n_estimators=1000, random_state=12)
rf.fit(X_train.T,Y_train.T)
accrf=rf.score(X_test.T,Y_test.T)*100
accuracies['Random Forest']=100
print("Random Forest Algorithm Accuracy Score: {:.2f}%".format(accrf))
# Out:
# Random Forest Algorithm Accuracy Score: 93.22%

# %%
from sklearn.svm import SVC
svm = SVC(random_state=1)
svm.fit(X_train.T,Y_train.T)
accsvm= svm.score(X_test.T, Y_test.T)*100
accuracies['SVM']=accsvm
print("Test Accuracy of SVM Algorithm: {:.2f}%".format(accsvm))
# Out:
# Test Accuracy of SVM Algorithm: 77.25%

# %%
from sklearn.tree import DecisionTreeClassifier
dt= DecisionTreeClassifier(random_state=0)
dt.fit(X_train.T,Y_train.T)
accdt=dt.score(X_test.T, Y_test.T)*100
accuracies['DT']=accdt
print("Test Accuracy of DECISON TREE Algorithm: {:.2f}%".format(accdt))
# Out:
# Test Accuracy of DECISON TREE Algorithm: 94.05%

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train.T,Y_train.T)
accgnb=gnb.score(X_test.T,Y_test.T)*100
accuracies['GNB']=100
print("Navies Bayes Accuracy Score: {:.2f}%".format(accgnb))
# Out:
# Navies Bayes Accuracy Score: 78.58%

# %%
plt.bar(['LR'],[acclr], label="DT", color='purple')
plt.bar(['RF'],[accrf], label="RF", color='green')
plt.bar(['KNN'],[accknn], label="KNN", color='orange')
plt.bar(['DT'],[accdt], label="DT", color='blue')
plt.bar(['SVM'],[accsvm], label="SVM", color='#CFC60E')
plt.bar(['NB'],[accgnb], label="NB", color='black')

plt.ylabel("Accuracy %")
plt.xlabel("Algorithms")
plt.figure(figsize=(10,5))

plt.show()

# %%
import numpy as np
#data=np.to_numpy([60.7220,153.6700,10.00,4.7,158,6.0,0,0.030,4,228.00,0.6946,1.5,1.0500])
data=pd.DataFrame([60.7220,153.6700,10.00,4.7,158,6.0,0,0.030,4,228.00,0.6946,1.5,1.0500])
data
# Out:
#            0
# 0    60.7220
# 1   153.6700
# 2    10.0000
# 3     4.7000
# 4   158.0000
# 5     6.0000
# 6     0.0000
# 7     0.0300
# 8     4.0000
# 9   228.0000
# 10    0.6946
# 11    1.5000
# 12    1.0500

# %%
data=[[-21.2160,-179.2550,632.80,2.2,70,6.0,0,0.000,4,228.00,0.6946,1.5,1.0000]]

# %%
data=np.array(data)
print(data)
data=np.reshape(-1, 1)
# Out:
# [[ -21.216  -179.255   632.8       2.2      70.        6.        0.
#      0.        4.      228.        0.6946    1.5       1.    ]]

# %%
type(X_train)

# %%
data1=[[-17.9430,-178.4760,582.30,4.7,473,5.5,0,0.041,4,228.00,0.6946,1.5,0.8700]]

# %%
dt.predict(data1)
# Out:
# array([1])

# %%
def eqp(b):
    if dt.predict(b)==1:
        print("EARTH QUAKE DETECTED")
    else:  
        print("NO EARTQUAKE")

# %%
eqp(data1)
# Out:
# EARTH QUAKE DETECTED

# %%
nani=[[51.4470,-175.5580,33.00,4.7,149,5.8,0,0.071,4,228.00,0.6946,1.5,0.9800]]

# %%
dt.predict(nani)

# %%
eqp(nani)

# %%
batli=[[-60.7220,153.6700,10.00,4.7,158,6.0,0,0.030,4,228.00,0.6946,1.5,1.0500]]

# %%
eqp(batli)
# Out:
# EARTH QUAKE DETECTED
